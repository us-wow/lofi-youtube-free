# %% [markdown]
# # 🎵 무료 로파이 자동화 — Colab판
#
# **아무것도 설치할 필요 없어요. 내 컴퓨터 용량 0.** 구글 서버가 다 해줍니다.
#
# 왼쪽 ▶ 버튼을 위에서부터 차례로 누르세요.
#
# > 팁: 먼저 메뉴 **런타임 → 런타임 유형 변경 → GPU(T4)** 로 바꾸면 훨씬 빨라요.
# > 1번 설치 칸은 몇 분 걸립니다(AI 모델 다운로드, 한 번만).

# %%
# 1) 코드 받고 부품 설치 (몇 분 — 이 동안 커피 한 잔)
# (다시 눌러도 되도록 기존 폴더는 지우고 새로 받음)
# !rm -rf lofi-youtube-free
# !git clone https://github.com/us-wow/lofi-youtube-free.git
# %cd lofi-youtube-free
# !pip install -q -r requirements.txt

# %%
# 2) 키워드 → 곡 → 그림 → 영상까지 한 방에
# (medium 모델이라 곡당 2~4분 — '✅ 완성'이 보일 때까지 기다리세요)
# !python run.py

# %%
# 3) 만들어진 영상 바로 보기
import glob
from IPython.display import Video, display
mp4s = sorted(glob.glob('output/*.mp4'))
if not mp4s:
    print('아직 영상이 없어요. 위 2번 칸이 \"✅ 완성\"까지 끝났는지 확인하고 다시 ▶ 하세요.')
else:
    print('생성된 영상:', mp4s[-1])
    display(Video(mp4s[-1], embed=True))
